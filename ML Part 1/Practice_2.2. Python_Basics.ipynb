# %% [markdown]
# Programming Languages Used for Machien Learning:
# 1. Python
# 2. R

# %% [markdown]
# # Print function

# %%
print('Hello World')
# Out:
# Hello World

# %%
print("Machine Larning")
# Out:
# Machine Larning

# %%
print(7)
# Out:
# 7

# %%
print(7+2)
# Out:
# 9

# %% [markdown]
# # Basic Data types:
#
# 1.   int
# 2.   float
# 3.   str

# %%
type(7)
# Out:
# int

# %%
type(7.5)
# Out:
# float

# %%
type("Machien Learning")
# Out:
# str

# %% [markdown]
# # Constants & Variables

# %%
marvel_super_hero = "Iron Man"
print((marvel_super_hero))
# Out:
# Iron Man

# %%
marvel_super_hero = "Captain America"
print(marvel_super_hero)
# Out:
# Captain America

# %%
hero1, hero2, hero3 = "Iron Man", "Captain America", "Thor"
print(hero1)
print(hero2)
print(hero3)
# Out:
# Iron Man
# Captain America
# Thor

# %%
x=y=z=1
print(x)
print(y)
print(z)
# Out:
# 1
# 1
# 1

# %% [markdown]
# # input Function

# %%
number_1 = int(input("Enter the first Number  : "))
number_2 = int(input("Enter the second Number : "))

sum = number_1 + number_2

print(sum)
# Out:
# Enter the first Number  : 7
# Enter the second Number : 3
# 10

# %% [markdown]
# - # changing the data type in python:

# %%
num = 5
print(float)
# Out:
# <class 'float'>
