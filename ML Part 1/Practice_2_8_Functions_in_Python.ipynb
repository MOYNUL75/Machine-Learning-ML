# %% [markdown]
# # Function
# A function is a block of code that can be reused in a program to perform a specific task.
#
# **Syntax:**
# ```python
# def function_name(parameters):
#     # code block
#     return value   # optional

# %%
def add(a, b):
  return a + b

print(add(3, 4))
# Out:
# 7

# %%
def greet(name):
    print("Hello", name)

greet("Md Moynul Islam")
# Out:
# Hello Md Moynul Islam

# %%
def add(a, b):
    return a + b

result = add(5, 3)
print(result)
# Out:
# 8

# %%
def mul(a, b):
  print("Multiplication of two number :" ,a*b)

mul(2,3)
# Out:
# Multiplication of two number : 6

# %% [markdown]
# #### Factorial of a Number
# - The factorial of a number is the product of all positive integers less than or equal to the given number.
# - Factorial of 7 (7!): 7 x 6 x 5 x 4 x 3 x 2 x 1 = 5040

# %%
number = int(input("Enter a number to find it's factorial : "))

factorial = 1

if number < 0:
   print("Sorry, factorial does not exist for negative numbers")
elif number == 0:
   print("The factorial of 0 is 1")
else:
   for i in range(1, number + 1):
    factorial = factorial * i
   print('The factorial of ', number, 'is', factorial)
# Out:
# Enter a number to find it's factorial : 7
# The factorial of  7 is 5040

# %%
number = int(input("Enter a number to find it's factorial : "))

factorial = 1

if number < 0:
   print("Sorry, factorial does not exist for negative numbers")
elif number == 0:
   print("The factorial of 0 is 1")
else:
   for i in range(1, number + 1):
    factorial = factorial * i
   print('The factorial of ', number, 'is', factorial)
# Out:
# Enter a number to find it's factorial : -8
# Sorry, factorial does not exist for negative numbers

# %%
number = int(input("Enter a number to find it's factorial : "))

factorial = 1

if number < 0:
   print("Sorry, factorial does not exist for negative numbers")
elif number == 0:
   print("The factorial of 0 is 1")
else:
   for i in range(1, number + 1):
    factorial = factorial * i
   print('The factorial of ', number, 'is', factorial)
# Out:
# Enter a number to find it's factorial : 1
# The factorial of  1 is 1

# %% [markdown]
# #### Factorial Function

# %%
def factorial_value(num):
    factorial = 1

    if num < 0:
        return "Sorry, factorial does not exist for negative numbers"

    elif num == 0:
        return "The factorial of 0 is 1"

    else:
        for i in range(1, num + 1):
            factorial *= i
        return f"The factorial of {num} is : {factorial}"

# %%
factorial_value(0)
# Out:
# 'The factorial of 0 is 1'

# %%
factorial_value(-89)
# Out:
# 'Sorry, factorial does not exist for negative numbers'

# %%
factorial_value(7)
# Out:
# 'The factorial of 7 is : 5040'

# %%
factorial_value(10)
# Out:
# 'The factorial of 10 is : 3628800'

# %%
factorial_value(9)
# Out:
# 'The factorial of 9 is : 362880'

# %%
factorial_value(75)
# Out:
# 'The factorial of 75 is : 24809140811395398091946477116594033660926243886570122837795894512655842677572867409443815424000000000000000000'
